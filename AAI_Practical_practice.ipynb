# %%
import random
class Environment(object):
    def __init__(self):
      self.LocationCondition={'A':'0','B':'0'}
      self.LocationCondition['A']=random.randint(0,1)
      self.LocationCondition['B']=random.randint(0,1)
class SimpleRflexAgent(Environment):
    def __init__(self,Environment):
      score =0
      print(Environment.LocationCondition)
      VaccumLocation=random.randint(0,1)
      if VaccumLocation==0:
#myEnvironment=Environment()
#theVaccun=SimpleRflexAgent(myEnvironment)
        print('Vacuum has been placed at random place A.')
#
        if Environment.LocationCondition['A']==1:
           print('Place A is dirty.')
           Environment.LocationCondition['A']=0
           print('Place A has been cleaned now.')
           score +=1
        else:
             print('Place A is already clean.')
        print('Moving to Place B.')
        if Environment.LocationCondition['B']==1:
           print('Place B is dirty.')
           Environment.LocationCondition['B']=0
           print('Place B has been cleaned now.')
           score +=1
        else:
             print('Place B is already clean.')
      elif VaccumLocation==1:
            print('Vacuum is place randomly at place B.')

            if Environment.LocationCondition['A']==1:
              print('Place A is dirty.')
              Environment.LocationCondition['A']=0
              print('Place A has been cleaned now.')
              score +=1
            else:
                  print('Place A is already clean.')
                  print('Moving to Place B.')
            if Environment.LocationCondition['B']==1:
              print('Place B is dirty.')
              Environment.LocationCondition['B']=0
              print('Place B has been cleaned now.')
              score +=1
            else:
                print('Place B is already clean.')
      print('Environmnt is clean now')
      print(Environment.LocationCondition)
      print('Performance Measurement: ' + str(score))
theenvironment=Environment()
thevacuum=SimpleRflexAgent(theenvironment)
# Out:
# {'A': 0, 'B': 1}
# Vacuum has been placed at random place A.
# Place A is already clean.
# Moving to Place B.
# Place B is dirty.
# Place B has been cleaned now.
# Environmnt is clean now
# {'A': 0, 'B': 0}
# Performance Measurement: 1

# %%
import random
class Environment(object):
    def __init__(self):
      self.LocationCondition={'A':'0','B':'0'}
      self.LocationCondition['A']=random.randint(0,1)
      self.LocationCondition['B']=random.randint(0,1)
class SimpleReflexAgent(Environment):
    def __init__(self,Environment):
      score=0
      print(Environment.LocationCondition)
      if Environment.LocationCondition['A']!=1 and Environment.LocationCondition['B']!=1:
         print('Environment is already clean')
      else:
            VacuumLocation=random.randint(0,1)
            if VacuumLocation==1: #1 means place A and 0 means place B
              print('Vacuum placed at random place A.')
              if Environment.LocationCondition['A']==1:
                print('Place A is dirty.')
                Environment.LocationCondition['A']=0
                score +=1
                print('Place A has been cleaned now.')
              else:
                    print('Place A is already clean.')
              print('Vacuum has been moved to place B.')
              if Environment.LocationCondition['B']==1:
                  print('Place B is dirty.')
                  Environment.LocationCondition['B']=0
                  score +=1
                  print('Place B has been cleaned now.')
              else:
                    print('Place B is already clean.')
            elif VacuumLocation==0: #means at Place B
                  print('Vacuum placed at random place A.')
                  if Environment.LocationCondition['A']==1:
                    print('Place A is dirty.')
                    Environment.LocationCondition['A']=0
                    score +=1
                    print('Place A has been cleaned now.')
                  else:
                        print('Place A is already clean.')
                        print('Vacuum has been moved to place B.')
                  if Environment.LocationCondition['B']==1:
                      print('Place B is dirty.')
                      Environment.LocationCondition['B']=0
                      score +=1
                      print('Place B has been cleaned now.')
                  else:
                        print('Place B is already clean.')
            print(Environment.LocationCondition)
            print('Environment is clean now')
            print('performence: ' + str(score))
myenvironment=Environment()
myvacuum=SimpleReflexAgent(myenvironment)
# Out:
# {'A': 0, 'B': 0}
# Environment is already clean

# %%
import random
class SimpleReflexAgent(Environment):
    def __init__(self,Environment):
      self.LocationCondition={'A':'0','B':'0'}
      self.LocationCondition['A']=random.randint(0,1)
      self.LocationCondition['B']=random.randint(0,1)
      score=0
      print(Environment.LocationCondition)
      if Environment.LocationCondition['A']!=1 and Environment.LocationCondition['B']!=1:
         print('Environment is already clean')
      else:
            VacuumLocation=random.randint(0,1)
            if VacuumLocation==1: #1 means place A and 0 means place B
              print('Vacuum placed at random place A.')
              if Environment.LocationCondition['A']==1:
                print('Place A is dirty.')
                Environment.LocationCondition['A']=0
                score +=1
                print('Place A has been cleaned now.')
              else:
                    print('Place A is already clean.')
              print('Vacuum has been moved to place B.')
              if Environment.LocationCondition['B']==1:
                  print('Place B is dirty.')
                  Environment.LocationCondition['B']=0
                  score +=1
                  print('Place B has been cleaned now.')
              else:
                    print('Place B is already clean.')
            elif VacuumLocation==0: #means at Place B
                  print('Vacuum placed at random place A.')
                  if Environment.LocationCondition['A']==1:
                    print('Place A is dirty.')
                    Environment.LocationCondition['A']=0
                    score +=1
                    print('Place A has been cleaned now.')
                  else:
                        print('Place A is already clean.')
                        print('Vacuum has been moved to place B.')
                  if Environment.LocationCondition['B']==1:
                      print('Place B is dirty.')
                      Environment.LocationCondition['B']=0
                      score +=1
                      print('Place B has been cleaned now.')
                  else:
                        print('Place B is already clean.')
            print(Environment.LocationCondition)
            print('Environment is clean now')
            print('performence: ' + str(score))
myenvironment=Environment()
myvacuum=SimpleReflexAgent(myenvironment)

# %%
g={'1':['2','3','4'],#dictionary starts with {}
'2':['3','4'],
'3':['4','5'],
'4':['5'],
'5':[]}
v=[]#list starts with []
q=[]
def bfs(v,g,n):
  v.append(n)
  q.append(n)
  while q:
      #print(q)
      x=q.pop(0)
      print(x,end=",")
      #print(g[x]) #g[1]
      for nei in g[x]:
        if nei not in v:
          v.append(nei)
          q.append(nei)
bfs(v,g,'1')
# Out:
# 1,2,3,4,5,

# %%
g={'1':['2','3','4'],
   '2':['3','4'],
   '3':['4','5'],
   '4':['5'],
   '5':[]}
v=[]
q=[]
def bfs(v,g,n,q):
  v.append(n)
  q.append(n)
  while q:
      x=q.pop(0)
      print(x,end=' ')
      for ne in g[x]:
        if ne not in v:
          v.append(ne)
          q.append(ne)
bfs(v,g,'1',q)
# Out:
# 1 2 3 4 5

# %%
g={'1':['2','3','4'],
   '2':['3','4'],
   '3':['4','5'],
   '4':['5'],
   '5':[]}
v=[]
q=[]
def bfs(g,v,q,n):
  v.append(n)
  q.append(n)
  while q:
      x=q.pop(0)
      print(x,end=' ')
      for nei in g[x]:
        if nei not in v:
          v.append(nei)
          q.append(nei)
bfs(g,v,q,'1')
# Out:
# 1 2 3 4 5

# %%
g={'1':['2','3','4'],
'2':['3','4'],
'3':['4','5'],
'4':['5'],
'5':[]}
v=[]
def dfs(v,g,n):
  if n not in v:
    print(n,end=" ")
    v.append(n)
    for nei in g[n]:
      dfs(v,g,nei)
dfs(v,g,'1')
# Out:
# 1 2 3 4 5

# %%
g={'1':['2','3','4'],
'2':['3','4'],
'3':['4','5'],
'4':['5'],
'5':[]}
v=[]
def dfs(g,v,n):
  if n  not in v:
    print(n,end=' ')
    v.append(n)
    for nei in g[n]:
      dfs(g,v,nei)
dfs(g,v,'1')
# Out:
# 1 2 3 4 5

# %%
# !pip install scikit-fuzzy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894079 sha256=0c519653f66854a71da1b05753e251be305ca5d31ab514427d1b8fdb9aa6f960
#   Stored in directory: /root/.cache/pip/wheels/4f/86/1b/dfd97134a2c8313e519bcebd95d3fedc7be7944db022094bc8
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

x = np.arange(0, 11, 1)  # Universe of discourse from 0 to 10
a = 2
b = 5
c = 8

# Create a triangular membership function
membership = fuzz.trimf(x, [a, b, c])
#fig, (ax0, ax1, ax2) = plt.subplots(nrows=3, figsize=(8, 9))
# Plot the membership function
plt.plot(x, membership)
plt.xlabel('Value')
plt.ylabel('Membership Degree')
plt.title('Triangular Membership Function')
plt.grid(True)
plt.show()

# %%
import numpy as np
# !pip install scikit-fuzzy
import skfuzzy as fuzz

# %%
import matplotlib.pyplot as plt

# %%
x=np.arange(0,11,1)
membership1=fuzz.trimf(x,[0,0,5])
plt.plot(x,membership1)
plt.xlabel('value')
plt.ylabel('membership')
plt.title('title')
plt.grid()
plt.show()
